# %%
import pandas as pd
#Scraping With GetOldTweets3
#!pip install GetOldTweets3
import GetOldTweets3 as got

# Trying date 
#import datetime as dt
#start_date = dt.datetime(2020, 01,01)
#end_date = dt.datetime(2020, 01,31)
#total_days = (end_date - start_date).days + 7 (7 days in week)
#for day_number in range(total_days):
#    current_date = (start_date + dt.timedelta(days = day_number)).date()

keyword = "stockmarket"
oldest_date = "2020-01-01"    
newest_date = "2020-01-07"
number_tweets = 500

# %%
tweet_criteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                            .setSince(oldest_date)\
                                            .setUntil(newest_date)\
                                            .setTopTweets(True)\
                                            .setMaxTweets(500)

tweet_df = pd.DataFrame({'got_criteria':got.manager.TweetManager.getTweets(tweet_criteria)})
#tweet_df = pd.DataFrame({'got_criteria':got.manager.TweetManager.getTweets(tweet_criteria)[0]})
tweet_df
# Out:
#                                           got_criteria
# 0    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# ..                                                 ...
# 363  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 364  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 365  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 366  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 367  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
# [368 rows x 1 columns]

# %%
tweet_df["tweet_text"] = tweet_df["got_criteria"].apply(lambda x: x.text)
tweet_df["tweet_text"]

tweet_df["date"] = tweet_df["got_criteria"].apply(lambda x: x.date)
tweet_df["date"]

tweet_df["hashtags"] = tweet_df["got_criteria"].apply(lambda x: x.hashtags)
tweet_df["hashtags"]

tweet_df["link"] = tweet_df["got_criteria"].apply(lambda x: x.permalink)
tweet_df["link"]
# Out:
# 0      https://twitter.com/Fibonacciqueen/status/1214...
# 1      https://twitter.com/FitradersRick/status/12143...
# 2      https://twitter.com/DekmarTrades/status/121431...
# 3      https://twitter.com/LibertyBlitz/status/121429...
# 4      https://twitter.com/Forbes/status/121427544750...
#                              ...
# 363    https://twitter.com/campbellkevin74/status/121...
# 364    https://twitter.com/IBDinvestors/status/121216...
# 365    https://twitter.com/scbona/status/121216171793...
# 366    https://twitter.com/upserny/status/12121615547...
# 367    https://twitter.com/_JoseNajarro/status/121216...
# Name: link, Length: 368, dtype: object

# %%
pd.options.display.max_columns
#tweet_df


from datetime import datetime as dt
tweet_df['date'] = tweet_df['date'].dt.normalize()
tweet_df['date'] = tweet_df['date'].dt.strftime('%Y-%m-%d')
tweet_df
# Out:
#                                           got_criteria  \
# 0    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4    <GetOldTweets3.models.Tweet.Tweet object at 0x...
# ..                                                 ...
# 363  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 364  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 365  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 366  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 367  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
#                                             tweet_text        date  \
# 0    We have a time/price decision in $RH. An entry...  2020-01-06
# 1    Recap $labs $cgc $pton $uber $amzn $vlns $gold...  2020-01-06
# 2    My biggest accomplishment is that I made a lif...  2020-01-06
# 3    Phase 1 withdrawal from Iraq canceled. Until t...  2020-01-06
# 4    While escalating tensions in the Middle East d...  2020-01-06
# ..                                                 ...         ...
# 363  About half...but the thing is, like wealth in ...  2020-01-01
# 364  Make 2020 your most profitable year yet with I...  2020-01-01
# 365  A) Economy does not equal stock market B) Y'al...  2020-01-01
# 366                         Yes, but the stock market.  2020-01-01
# 367  $NVDA has a small shareholder return, they pay...  2020-01-01
#
#                                               hashtags  \
# 0    #Trading #FibonacciQueen #StocksToTrade #stock...
# 1    #stocks #StockMarkets #StockMarket #stockstowa...
# 2
# 3
# 4
# ..                                                 ...
# 363
# 364  #stocks #trading #investing #stockmarket #NewYear
# 365                                     #SwampGrifters
# 366
# 367         #Investment #HappyNewyear2020 #stockmarket
#
#                                                   link
# 0    https://twitter.com/Fibonacciqueen/status/1214...
# 1    https://twitter.com/FitradersRick/status/12143...
# 2    https://twitter.com/DekmarTrades/status/121431...
# 3    https://twitter.com/LibertyBlitz/status/121429...
# 4    https://twitter.com/Forbes/status/121427544750...
# ..                                                 ...
# 363  https://twitter.com/campbellkevin74/status/121...
# 364  https://twitter.com/IBDinvestors/status/121216...
# 365  https://twitter.com/scbona/status/121216171793...
# 366  https://twitter.com/upserny/status/12121615547...
# 367  https://twitter.com/_JoseNajarro/status/121216...
#
# [368 rows x 5 columns]

# %%
tweet_df.to_excel("tweet1.xlsx")
