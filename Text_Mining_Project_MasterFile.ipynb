# %%
import pandas as pd
#Scraping With GetOldTweets3
#!pip install GetOldTweets3
import datetime as dt
import GetOldTweets3 as got
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import RegexpTokenizer
import re
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
import textblob as TextBlob
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer

# %%
keyword = 'stockmarket'
old_date = '2020-01-01'
new_date = '2020-03-31'
number_tweets = 800

# %%
def get_stock_tweet(old_date,new_date):
    tweet_criteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                            .setSince(old_date)\
                                            .setUntil(new_date)\
                                            .setTopTweets(True)\
                                            .setMaxTweets(number_tweets)
    return(got.manager.TweetManager.getTweets(tweet_criteria))

# %%
import datetime as dt
#start_date = dt.datetime(2020, 01,01)
start_date_str = "03/31/20"
end_date_str='01/01/20'
start_date = dt.datetime.strptime(start_date_str, "%m/%d/%y")
end_date=dt.datetime.strptime(end_date_str, "%m/%d/%y")
all_tweets =[]
while start_date > end_date:
    tmp_date = start_date - dt.timedelta(days=7)
    print("start_date:",start_date," end_date",tmp_date)
    
    all_tweets.extend(get_stock_tweet(tmp_date.strftime("%Y-%m-%d"),start_date.strftime("%Y-%m-%d")))
    start_date=tmp_date
# Out:
# start_date: 2020-03-31 00:00:00  end_date 2020-03-24 00:00:00
# start_date: 2020-03-24 00:00:00  end_date 2020-03-17 00:00:00
# start_date: 2020-03-17 00:00:00  end_date 2020-03-10 00:00:00
# start_date: 2020-03-10 00:00:00  end_date 2020-03-03 00:00:00
# start_date: 2020-03-03 00:00:00  end_date 2020-02-25 00:00:00
# start_date: 2020-02-25 00:00:00  end_date 2020-02-18 00:00:00
# start_date: 2020-02-18 00:00:00  end_date 2020-02-11 00:00:00
# start_date: 2020-02-11 00:00:00  end_date 2020-02-04 00:00:00
# start_date: 2020-02-04 00:00:00  end_date 2020-01-28 00:00:00
# start_date: 2020-01-28 00:00:00  end_date 2020-01-21 00:00:00
# start_date: 2020-01-21 00:00:00  end_date 2020-01-14 00:00:00
# start_date: 2020-01-14 00:00:00  end_date 2020-01-07 00:00:00
# start_date: 2020-01-07 00:00:00  end_date 2019-12-31 00:00:00

# %%
tweet_df = pd.DataFrame({'got_criteria':all_tweets})
tweet_df
# Out:
#                                            got_criteria
# 0     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# ...                                                 ...
# 7724  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7725  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7726  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7727  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7728  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
# [7729 rows x 1 columns]

# %%
tweet_df["tweet_text"] = tweet_df["got_criteria"].apply(lambda x: x.text)
tweet_df["tweet_text"]

tweet_df["date"] = tweet_df["got_criteria"].apply(lambda x: x.date)
tweet_df["date"]

tweet_df["hashtags"] = tweet_df["got_criteria"].apply(lambda x: x.hashtags)
tweet_df["hashtags"]

tweet_df["link"] = tweet_df["got_criteria"].apply(lambda x: x.permalink)
#tweet_df["link"]

# %%
#tweet_df
from datetime import datetime as dt
tweet_df['date'] = tweet_df['date'].dt.normalize()
tweet_df['date'] = tweet_df['date'].dt.strftime('%Y-%m-%d')
tweet_df
# Out:
#                                            got_criteria  \
# 0     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4     <GetOldTweets3.models.Tweet.Tweet object at 0x...
# ...                                                 ...
# 7724  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7725  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7726  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7727  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7728  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
#                                              tweet_text        date  \
# 0     Also he’s an unread malignant narcissist who’s...  2020-03-30
# 1     Just swap the COVID graphs with the stock mark...  2020-03-30
# 2     so i think i might’ve waited to long to buy a ...  2020-03-30
# 3     "The stock market is a beast like no other: in...  2020-03-30
# 4     "Liquidity shall never freeze again" ICE9 -> S...  2020-03-30
# ...                                                 ...         ...
# 7724  Should You Consider The ‘Lite Beer Of Investin...  2019-12-31
# 7725  Lundin-Gold-Inc. is Top Pick at StockChase htt...  2019-12-31
# 7726  They r ramping up in Ecuador. He has be...Lund...  2019-12-31
# 7727  FREE TRIAL! Ready for a green 2020??? Check ou...  2019-12-31
# 7728  #FromTheCenter: Stocks on Track for Best Year ...  2019-12-31
#
#                                                hashtags  \
# 0
# 1
# 2
# 3                         #stocks #investing #wjoquotes
# 4
# ...                                                 ...
# 7724             #investing #stockmarket #stocks #bonds
# 7725          #stocks #finance #stockmarket #StockPicks
# 7726          #stocks #finance #stockmarket #StockPicks
# 7727  #trading #DayTrading #WallStreet #StockMarket ...
# 7728                 #FromTheCenter #StockMarket #SP500
#
#                                                    link
# 0     https://twitter.com/SuttleBuddy/status/1244775...
# 1     https://twitter.com/NotUrplePingo/status/12447...
# 2     https://twitter.com/Skoog/status/1244763879156...
# 3     https://twitter.com/williamoneilco/status/1244...
# 4     https://twitter.com/Paisan26849860/status/1244...
# ...                                                 ...
# 7724  https://twitter.com/iris_xyz/status/1211799307...
# 7725  https://twitter.com/stockchase/status/12117992...
# 7726  https://twitter.com/stockchase/status/12117992...
# 7727  https://twitter.com/TeresaTrades/status/121179...
# 7728  https://twitter.com/AllSidesNow/status/1211799...
#
# [7729 rows x 5 columns]

# %%
#tweet_df.to_excel("tweet_data_master.xlsx")
# Out:
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://www.youtube.com/watch?v=X2bw93MtAtg%20Trumps%20approval%20has%20not%20really%20taken%20a%20hit%20from%20coronavirus%20or%20the%20stock%20market%20freefall%20of%20last%20week.%20If%20anything%20it%20may%20rise%20since%20the%20majority%20of%20Americans%20approve%20of%20his%20response.%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://www.washingtonpost.com/opinions/2020/03/20/lets-get-through-this-pandemic-with-little-trump-possible/%20Keep%20putting%20this%20deranged%20sociopath%20in%20front%20of%20television%20screens%20and%20the%20stock%20market%20will%20evaporate.%20Worse...so%20many%20will%20die.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://www.youtube.com/watch?v=fiNytfSTvwc%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://www.westernjournal.com/cdc-official-helping-spook-trumps-economy-coronavirus-fears-rod-rosensteins-sister/%20You%20know%20the%20CDC%20official%20trying%20to%20help%20the%20left%20destroy%20the%20economy%20and%20stock%20market%20is%20none%20other%20than%20Rod%20Rosenstein's%20sister.%20This%20is%20the%20one%20who%20said%20an%20outbreak%20was%20inevitable%20and%20that%20major%20changes,%20school%20closings%20and%20such%20would%20need%20to%20happen' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://youtu.be/PlDz7C8KdL8%20@stonesour%20HELL%20&amp;%20CO%20CONSEQUENCES%20.%20I%20REFUSE%20TO%20DIE!%20WAKE%20UP!%20STOCK%20MARKET%20%5d666%5b%20.%20HERE%20COMES%20WHAT%20YOU%20ALL%20ASKED%20FOR.%20REMEMBER,%20THE%20ENDING%20IS%20(SIC)%20AND%20WILL%20NOT%20BE%20FOR%20ALL.%20THESE%20PEOPLE%20ARE%20EVIL.%20*+*%20https://twitter.com/MAGAMNCD8/status/1223242383187423232' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/priyankakushwaha/opt/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:931: UserWarning: Ignoring URL 'https://youtu.be/s-t2NB9h9S4%20@Metallica%20S&amp;D%20.%20.%20._...-&lt;-..%20.........%20Water%20Bo-Y%20Or%20(i)%20..%20No%20Matter%20Which%20Way%20Or%20Angle%20You%20Come%20At%20Thi%20One.%20..,All%20Ends%20The%20Same%20..%20%5b666%5d%20Stock%20Market%20/2008:,%20This%20Time%20It%20Will%20Be%20To%20Do%20What..?%20Reset..?%20%5bMSM%5d%20Must%20Fall%20First%20.%20%5bTHEY%5d%20Fell%20*+*%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
data = pd.read_excel("tweet_data_master.xlsx")
#data
# Out:
#       Unnamed: 0                                       got_criteria  \
# 0              0  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1              1  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2              2  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3              3  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4              4  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# ...          ...                                                ...
# 7724        7724  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7725        7725  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7726        7726  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7727        7727  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 7728        7728  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
#                                              tweet_text        date  \
# 0     Also he’s an unread malignant narcissist who’s...  2020-03-30
# 1     Just swap the COVID graphs with the stock mark...  2020-03-30
# 2     so i think i might’ve waited to long to buy a ...  2020-03-30
# 3     "The stock market is a beast like no other: in...  2020-03-30
# 4     "Liquidity shall never freeze again" ICE9 -> S...  2020-03-30
# ...                                                 ...         ...
# 7724  Should You Consider The ‘Lite Beer Of Investin...  2019-12-31
# 7725  Lundin-Gold-Inc. is Top Pick at StockChase htt...  2019-12-31
# 7726  They r ramping up in Ecuador. He has be...Lund...  2019-12-31
# 7727  FREE TRIAL! Ready for a green 2020??? Check ou...  2019-12-31
# 7728  #FromTheCenter: Stocks on Track for Best Year ...  2019-12-31
#
#                                                hashtags  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                         #stocks #investing #wjoquotes
# 4                                                   NaN
# ...                                                 ...
# 7724             #investing #stockmarket #stocks #bonds
# 7725          #stocks #finance #stockmarket #StockPicks
# 7726          #stocks #finance #stockmarket #StockPicks
# 7727  #trading #DayTrading #WallStreet #StockMarket ...
# 7728                 #FromTheCenter #StockMarket #SP500
#
#                                                    link
# 0     https://twitter.com/SuttleBuddy/status/1244775...
# 1     https://twitter.com/NotUrplePingo/status/12447...
# 2     https://twitter.com/Skoog/status/1244763879156...
# 3     https://twitter.com/williamoneilco/status/1244...
# 4     https://twitter.com/Paisan26849860/status/1244...
# ...                                                 ...
# 7724  https://twitter.com/iris_xyz/status/1211799307...
# 7725  https://twitter.com/stockchase/status/12117992...
# 7726  https://twitter.com/stockchase/status/12117992...
# 7727  https://twitter.com/TeresaTrades/status/121179...
# 7728  https://twitter.com/AllSidesNow/status/1211799...
#
# [7729 rows x 6 columns]

# %%
data.tweet_text.fillna("", inplace=True)
data.tweet_text.dtype
# Out:
# dtype('O')

# %%
data['word_count'] = data['tweet_text'].apply(lambda x: len(str(x).split(" ")))
#data.head(10)

# %%
import string
data['no_punctuation'] = data['tweet_text'].str.replace('[^\w\s]','')
data.head()
# Out:
#    Unnamed: 0                                       got_criteria  \
# 0           0  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1           1  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2           2  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3           3  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4           4  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
#                                           tweet_text        date  \
# 0  Also he’s an unread malignant narcissist who’s...  2020-03-30
# 1  Just swap the COVID graphs with the stock mark...  2020-03-30
# 2  so i think i might’ve waited to long to buy a ...  2020-03-30
# 3  "The stock market is a beast like no other: in...  2020-03-30
# 4  "Liquidity shall never freeze again" ICE9 -> S...  2020-03-30
#
#                         hashtags  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  #stocks #investing #wjoquotes
# 4                            NaN
#
#                                                 link  word_count  \
# 0  https://twitter.com/SuttleBuddy/status/1244775...          44
# 1  https://twitter.com/NotUrplePingo/status/12447...          13
# 2  https://twitter.com/Skoog/status/1244763879156...          42
# 3  https://twitter.com/williamoneilco/status/1244...          36
# 4  https://twitter.com/Paisan26849860/status/1244...          26
#
#                                       no_punctuation
# 0  Also hes an unread malignant narcissist whos f...
# 1  Just swap the COVID graphs with the stock mark...
# 2  so i think i mightve waited to long to buy a S...
# 3  The stock market is a beast like no other indi...
# 4  Liquidity shall never freeze again ICE9  Stock...

# %%
tok = WordPunctTokenizer()
ps = PorterStemmer() 

pat1 = r'@[A-Za-z0-9_]+'
pat2 = r'https?://[^ ]+'
combined_pat = r'|'.join((pat1, pat2))
www_pat = r'www.[^ ]+'
negations_dic = {"he’s":"he is","isn't":"is not", "aren't":"are not", "wasn't":"was not", "weren't":"were not",
                "haven't":"have not","hasn't":"has not","hadn't":"had not","won't":"will not",
                "wouldn't":"would not", "don't":"do not", "doesn't":"does not","didn't":"did not",
                "can't":"can not","couldn't":"could not","shouldn't":"should not","mightn't":"might not",
                "mustn't":"must not", "might’ve": "might have","y’all":"you all","we're":"we are","you’re":"you "}
neg_pattern = re.compile(r'\b(' + '|'.join(negations_dic.keys()) + r')\b')

def clean_tweet(text):
    try:
        soup = BeautifulSoup(text,'lxml')
        souped = soup.get_text()
    except:
        souped = ""
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    try:
        bom_removed = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        bom_removed = souped
    stripped = re.sub(combined_pat, '', bom_removed)
    stripped = re.sub(www_pat, '', stripped)
    lower_case = stripped.lower()
    neg_handled = neg_pattern.sub(lambda x: negations_dic[x.group()], lower_case)
    letters_only = re.sub("[^a-zA-Z]", " ", neg_handled)
    words = [x for x  in tok.tokenize(letters_only) if len(x) > 1]
    words_without_sw = [word for word in words if not word in stopwords.words()] # Remove stop words
    #print("words_without_sw")
    stem_words = [ps.stem(word) for word in words_without_sw] #convert to stem word
    #print("stem_words")
    return (" ".join(stem_words)).strip()

# %%
result = []

for tweet in data.tweet_text:
    result.append(clean_tweet(tweet))

data['cleaned_text'] = result

data.head()
# Out:
#    Unnamed: 0                                       got_criteria  \
# 0           0  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 1           1  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 2           2  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 3           3  <GetOldTweets3.models.Tweet.Tweet object at 0x...
# 4           4  <GetOldTweets3.models.Tweet.Tweet object at 0x...
#
#                                           tweet_text        date  \
# 0  Also he’s an unread malignant narcissist who’s...  2020-03-30
# 1  Just swap the COVID graphs with the stock mark...  2020-03-30
# 2  so i think i might’ve waited to long to buy a ...  2020-03-30
# 3  "The stock market is a beast like no other: in...  2020-03-30
# 4  "Liquidity shall never freeze again" ICE9 -> S...  2020-03-30
#
#                         hashtags  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  #stocks #investing #wjoquotes
# 4                            NaN
#
#                                                 link  word_count  \
# 0  https://twitter.com/SuttleBuddy/status/1244775...          44
# 1  https://twitter.com/NotUrplePingo/status/12447...          13
# 2  https://twitter.com/Skoog/status/1244763879156...          42
# 3  https://twitter.com/williamoneilco/status/1244...          36
# 4  https://twitter.com/Paisan26849860/status/1244...          26
#
#                                       no_punctuation  \
# 0  Also hes an unread malignant narcissist whos f...
# 1  Just swap the COVID graphs with the stock mark...
# 2  so i think i mightve waited to long to buy a S...
# 3  The stock market is a beast like no other indi...
# 4  Liquidity shall never freeze again ICE9  Stock...
#
#                                         cleaned_text
# 0  unread malign narcissist forethought end next ...
# 1  swap covid graph stock market graph boom probl...
# 2  think might wait long buy switch everywher sol...
# 3  stock market beast like indiffer human desir o...
# 4  liquid shall never freez ice stockmarket close...

# %%
data.to_excel("clean_tweet_data_master.xlsx")
